# %%
import numpy as np
import tensorflow as tf
import tensorflow.keras as keras
tf.keras.backend.set_floatx('float64')

# Data Preparation
X_train = np.load('data_mnist/X_train.npy', allow_pickle=True)
y_train = np.load('data_mnist/y_train.npy', allow_pickle=True)
X_test = np.load('data_mnist/X_test.npy', allow_pickle=True)
y_test = np.load('data_mnist/y_test.npy', allow_pickle=True)

X_train = X_train/255
X_test  = X_test/255

print(X_train.shape)
# Out:
# (60000, 784)

# %%
import numpy as np
import tensorflow as tf
import tensorflow.keras as keras
tf.keras.backend.set_floatx('float64')

# Data Preparation
X_train = np.load('data_mnist/X_train.npy', allow_pickle=True)
y_train = np.load('data_mnist/y_train.npy', allow_pickle=True)
X_test = np.load('data_mnist/X_test.npy', allow_pickle=True)
y_test = np.load('data_mnist/y_test.npy', allow_pickle=True)

X_train = X_train/255
X_test  = X_test/255


batch_size = 512
epochs = 50

# create model
model = tf.keras.Sequential()
model.add(tf.keras.Input(shape=(784,)))
model.add(tf.keras.layers.Dense(10, activation='softmax', 
                               kernel_initializer=keras.initializers.RandomNormal(stddev=0.01),
                               bias_initializer=keras.initializers.Zeros()))

# declare optimization method and loss function
model.compile(optimizer='sgd', 
              loss='sparse_categorical_crossentropy', 
              metrics=['accuracy'])

# training
history = model.fit(X_train, y_train, batch_size, epochs)

# testing
test_loss, test_acc = model.evaluate(X_test, y_test, verbose=0)
print('\n\nTest accuracy:', test_acc)
# Out:
# Train on 60000 samples
# Epoch 1/50
# 60000/60000 [==============================] - 1s 24us/sample - loss: 1.8287 - accuracy: 0.6726
# Epoch 2/50
# 60000/60000 [==============================] - 1s 10us/sample - loss: 1.2695 - accuracy: 0.7992
# Epoch 3/50
# 60000/60000 [==============================] - 1s 10us/sample - loss: 1.0119 - accuracy: 0.8231
# Epoch 4/50
# 60000/60000 [==============================] - 1s 10us/sample - loss: 0.8703 - accuracy: 0.8352
# Epoch 5/50
# 60000/60000 [==============================] - 1s 10us/sample - loss: 0.7810 - accuracy: 0.8430
# Epoch 6/50
# 60000/60000 [==============================] - 1s 10us/sample - loss: 0.7191 - accuracy: 0.8491
# Epoch 7/50
# 60000/60000 [==============================] - 1s 11us/sample - loss: 0.6734 - accuracy: 0.8540
# Epoch 8/50
# 60000/60000 [==============================] - 1s 11us/sample - loss: 0.6381 - accuracy: 0.8579
# Epoch 9/50
# 60000/60000 [==============================] - 1s 10us/sample - loss: 0.6098 - accuracy: 0.8611
# Epoch 10/50
# 60000/60000 [==============================] - 1s 11us/sample - loss: 0.5867 - accuracy: 0.8640
# Epoch 11/50
# 60000/60000 [==============================] - 1s 10us/sample - loss: 0.5672 - accuracy: 0.8667
# Epoch 12/50
# 60000/60000 [==============================] - ETA: 0s - loss: 0.5510 - accuracy: 0.86 - 1s 10us/sample - loss: 0.5507 - accuracy: 0.8683
# Epoch 13/50
# 60000/60000 [==============================] - 1s 11us/sample - loss: 0.5363 - accuracy: 0.8700
# Epoch 14/50
# 60000/60000 [==============================] - 1s 12us/sample - loss: 0.5237 - accuracy: 0.8718s - loss: 0
# Epoch 15/50
# 60000/60000 [==============================] - 1s 12us/sample - loss: 0.5126 - accuracy: 0.8736
# Epoch 16/50
# 60000/60000 [==============================] - 1s 12us/sample - loss: 0.5027 - accuracy: 0.8747
# Epoch 17/50
# 60000/60000 [==============================] - 1s 10us/sample - loss: 0.4938 - accuracy: 0.8767
# Epoch 18/50
# 60000/60000 [==============================] - 1s 12us/sample - loss: 0.4857 - accuracy: 0.8777
# Epoch 19/50
# 60000/60000 [==============================] - 1s 10us/sample - loss: 0.4784 - accuracy: 0.8786
# Epoch 20/50
# 60000/60000 [==============================] - 1s 11us/sample - loss: 0.4716 - accuracy: 0.8800
# Epoch 21/50
# 60000/60000 [==============================] - 1s 11us/sample - loss: 0.4654 - accuracy: 0.8809
# Epoch 22/50
# 60000/60000 [==============================] - ETA: 0s - loss: 0.4601 - accuracy: 0.88 - 1s 12us/sample - loss: 0.4597 - accuracy: 0.8818
# Epoch 23/50
# 60000/60000 [==============================] - 1s 12us/sample - loss: 0.4544 - accuracy: 0.8827
# Epoch 24/50
# 60000/60000 [==============================] - 1s 12us/sample - loss: 0.4494 - accuracy: 0.8838
# Epoch 25/50
# 60000/60000 [==============================] - 1s 12us/sample - loss: 0.4448 - accuracy: 0.8845
# Epoch 26/50
# 60000/60000 [==============================] - 1s 12us/sample - loss: 0.4405 - accuracy: 0.8852
# Epoch 27/50
# 60000/60000 [==============================] - 1s 12us/sample - loss: 0.4364 - accuracy: 0.8858
# Epoch 28/50
# 60000/60000 [==============================] - 1s 13us/sample - loss: 0.4326 - accuracy: 0.8868
# Epoch 29/50
# 60000/60000 [==============================] - 1s 11us/sample - loss: 0.4290 - accuracy: 0.8873
# Epoch 30/50
# 60000/60000 [==============================] - 1s 11us/sample - loss: 0.4256 - accuracy: 0.8880
# Epoch 31/50
# 60000/60000 [==============================] - 1s 11us/sample - loss: 0.4223 - accuracy: 0.8884
# Epoch 32/50
# 60000/60000 [==============================] - 1s 10us/sample - loss: 0.4193 - accuracy: 0.8890
# Epoch 33/50
# 60000/60000 [==============================] - 1s 11us/sample - loss: 0.4164 - accuracy: 0.8897
# Epoch 34/50
# 60000/60000 [==============================] - 1s 11us/sample - loss: 0.4136 - accuracy: 0.8899
# Epoch 35/50
# 60000/60000 [==============================] - 1s 11us/sample - loss: 0.4109 - accuracy: 0.8905
# Epoch 36/50
# 60000/60000 [==============================] - 1s 11us/sample - loss: 0.4084 - accuracy: 0.8912
# Epoch 37/50
# 60000/60000 [==============================] - 1s 11us/sample - loss: 0.4060 - accuracy: 0.8915
# Epoch 38/50
# 60000/60000 [==============================] - 1s 11us/sample - loss: 0.4036 - accuracy: 0.8921
# Epoch 39/50
# 60000/60000 [==============================] - 1s 11us/sample - loss: 0.4014 - accuracy: 0.8925
# Epoch 40/50
# 60000/60000 [==============================] - 1s 11us/sample - loss: 0.3992 - accuracy: 0.8930
# Epoch 41/50
# 60000/60000 [==============================] - 1s 12us/sample - loss: 0.3972 - accuracy: 0.8937
# Epoch 42/50
# 60000/60000 [==============================] - 1s 13us/sample - loss: 0.3952 - accuracy: 0.8937
# Epoch 43/50
# 60000/60000 [==============================] - 1s 14us/sample - loss: 0.3933 - accuracy: 0.8943
# Epoch 44/50
# 60000/60000 [==============================] - 1s 12us/sample - loss: 0.3914 - accuracy: 0.8948
# Epoch 45/50
# 60000/60000 [==============================] - 1s 11us/sample - loss: 0.3897 - accuracy: 0.8950
# Epoch 46/50
# 60000/60000 [==============================] - 1s 11us/sample - loss: 0.3880 - accuracy: 0.8956
# Epoch 47/50
# 60000/60000 [==============================] - 1s 11us/sample - loss: 0.3863 - accuracy: 0.8957s - loss: 0.3
# Epoch 48/50
# 60000/60000 [==============================] - 1s 11us/sample - loss: 0.3847 - accuracy: 0.8962
# Epoch 49/50
# 60000/60000 [==============================] - 1s 13us/sample - loss: 0.3831 - accuracy: 0.8964
# Epoch 50/50
# 60000/60000 [==============================] - 1s 12us/sample - loss: 0.3816 - accuracy: 0.8966
#
#
# Test accuracy: 0.9034

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['loss'])
plt.xlabel('iteration')
plt.ylabel('Loss')
# Out:
# Text(0, 0.5, 'Loss')

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['accuracy'])
plt.xlabel('iteration')
plt.ylabel('Accuracy')
# Out:
# Text(0, 0.5, 'Accuracy')

# %%
# MLP - sigmoid

import numpy as np
import tensorflow as tf
import tensorflow.keras as keras
tf.keras.backend.set_floatx('float64')

# Data Preparation
X_train = np.load('data_mnist/X_train.npy', allow_pickle=True)
y_train = np.load('data_mnist/y_train.npy', allow_pickle=True)
X_test = np.load('data_mnist/X_test.npy', allow_pickle=True)
y_test = np.load('data_mnist/y_test.npy', allow_pickle=True)

X_train = X_train/255
X_test  = X_test/255


batch_size = 512
epochs = 50

# create model
model = tf.keras.Sequential()

model.add(tf.keras.Input(shape=(784,)))

model.add(tf.keras.layers.Dense(128, activation='sigmoid', 
                               kernel_initializer=keras.initializers.RandomNormal(stddev=0.01),
                               bias_initializer=keras.initializers.Zeros()))

model.add(tf.keras.layers.Dense(10, activation='softmax', 
                               kernel_initializer=keras.initializers.RandomNormal(stddev=0.01),
                               bias_initializer=keras.initializers.Zeros()))

# declare optimization method and loss function
model.compile(optimizer='sgd', 
              loss='sparse_categorical_crossentropy', 
              metrics=['accuracy'])

# training
history = model.fit(X_train, y_train, batch_size, epochs)

# testing
test_loss, test_acc = model.evaluate(X_test, y_test, verbose=0)
print('\n\nTest accuracy:', test_acc)
# Out:
# Train on 60000 samples
# Epoch 1/50
# 60000/60000 [==============================] - 2s 34us/sample - loss: 2.3005 - accuracy: 0.1107
# Epoch 2/50
# 60000/60000 [==============================] - 1s 25us/sample - loss: 2.2980 - accuracy: 0.1124
# Epoch 3/50
# 60000/60000 [==============================] - 1s 23us/sample - loss: 2.2955 - accuracy: 0.1124
# Epoch 4/50
# 60000/60000 [==============================] - 1s 24us/sample - loss: 2.2927 - accuracy: 0.1124
# Epoch 5/50
# 60000/60000 [==============================] - 1s 24us/sample - loss: 2.2892 - accuracy: 0.1126
# Epoch 6/50
# 60000/60000 [==============================] - 1s 24us/sample - loss: 2.2849 - accuracy: 0.1125
# Epoch 7/50
# 60000/60000 [==============================] - 1s 25us/sample - loss: 2.2793 - accuracy: 0.1172
# Epoch 8/50
# 60000/60000 [==============================] - 1s 25us/sample - loss: 2.2721 - accuracy: 0.1443
# Epoch 9/50
# 60000/60000 [==============================] - 2s 26us/sample - loss: 2.2628 - accuracy: 0.1802
# Epoch 10/50
# 60000/60000 [==============================] - 1s 24us/sample - loss: 2.2508 - accuracy: 0.2349
# Epoch 11/50
# 60000/60000 [==============================] - 1s 24us/sample - loss: 2.2352 - accuracy: 0.2724
# Epoch 12/50
# 60000/60000 [==============================] - 1s 24us/sample - loss: 2.2152 - accuracy: 0.3412s -
# Epoch 13/50
# 60000/60000 [==============================] - 1s 24us/sample - loss: 2.1899 - accuracy: 0.3702
# Epoch 14/50
# 60000/60000 [==============================] - 1s 25us/sample - loss: 2.1585 - accuracy: 0.4400
# Epoch 15/50
# 60000/60000 [==============================] - 1s 24us/sample - loss: 2.1201 - accuracy: 0.4453
# Epoch 16/50
# 60000/60000 [==============================] - 1s 24us/sample - loss: 2.0744 - accuracy: 0.4733
# Epoch 17/50
# 60000/60000 [==============================] - 1s 24us/sample - loss: 2.0212 - accuracy: 0.4902
# Epoch 18/50
# 60000/60000 [==============================] - 1s 24us/sample - loss: 1.9613 - accuracy: 0.5193
# Epoch 19/50
# 60000/60000 [==============================] - 1s 24us/sample - loss: 1.8958 - accuracy: 0.5323
# Epoch 20/50
# 60000/60000 [==============================] - 1s 23us/sample - loss: 1.8262 - accuracy: 0.5509
# Epoch 21/50
# 60000/60000 [==============================] - 1s 23us/sample - loss: 1.7545 - accuracy: 0.5714
# Epoch 22/50
# 60000/60000 [==============================] - 1s 24us/sample - loss: 1.6824 - accuracy: 0.5813
# Epoch 23/50
# 60000/60000 [==============================] - 1s 23us/sample - loss: 1.6114 - accuracy: 0.6008
# Epoch 24/50
# 60000/60000 [==============================] - 1s 24us/sample - loss: 1.5428 - accuracy: 0.6144
# Epoch 25/50
# 60000/60000 [==============================] - 1s 24us/sample - loss: 1.4775 - accuracy: 0.6284
# Epoch 26/50
# 60000/60000 [==============================] - 2s 26us/sample - loss: 1.4158 - accuracy: 0.6456
# Epoch 27/50
# 60000/60000 [==============================] - 2s 28us/sample - loss: 1.3581 - accuracy: 0.6626
# Epoch 28/50
# 60000/60000 [==============================] - 2s 28us/sample - loss: 1.3044 - accuracy: 0.6743
# Epoch 29/50
# 60000/60000 [==============================] - 1s 24us/sample - loss: 1.2545 - accuracy: 0.6895
# Epoch 30/50
# 60000/60000 [==============================] - 2s 25us/sample - loss: 1.2082 - accuracy: 0.7036
# Epoch 31/50
# 60000/60000 [==============================] - 2s 27us/sample - loss: 1.1653 - accuracy: 0.7140
# Epoch 32/50
# 60000/60000 [==============================] - 2s 26us/sample - loss: 1.1254 - accuracy: 0.7238
# Epoch 33/50
# 60000/60000 [==============================] - 2s 25us/sample - loss: 1.0883 - accuracy: 0.7365
# Epoch 34/50
# 60000/60000 [==============================] - 2s 26us/sample - loss: 1.0538 - accuracy: 0.7453
# Epoch 35/50
# 60000/60000 [==============================] - 1s 24us/sample - loss: 1.0215 - accuracy: 0.7539
# Epoch 36/50
# 60000/60000 [==============================] - 2s 28us/sample - loss: 0.9912 - accuracy: 0.7620
# Epoch 37/50
# 60000/60000 [==============================] - 1s 24us/sample - loss: 0.9628 - accuracy: 0.7681
# Epoch 38/50
# 60000/60000 [==============================] - 1s 24us/sample - loss: 0.9362 - accuracy: 0.7753
# Epoch 39/50
# 60000/60000 [==============================] - 1s 24us/sample - loss: 0.9110 - accuracy: 0.7814
# Epoch 40/50
# 60000/60000 [==============================] - 1s 24us/sample - loss: 0.8874 - accuracy: 0.7867
# Epoch 41/50
# 60000/60000 [==============================] - 2s 25us/sample - loss: 0.8651 - accuracy: 0.7924s
# Epoch 42/50
# 60000/60000 [==============================] - 2s 28us/sample - loss: 0.8441 - accuracy: 0.7974
# Epoch 43/50
# 60000/60000 [==============================] - 2s 25us/sample - loss: 0.8242 - accuracy: 0.8020
# Epoch 44/50
# 60000/60000 [==============================] - 2s 25us/sample - loss: 0.8054 - accuracy: 0.8068
# Epoch 45/50
# 60000/60000 [==============================] - 1s 25us/sample - loss: 0.7876 - accuracy: 0.8095
# Epoch 46/50
# 60000/60000 [==============================] - 2s 25us/sample - loss: 0.7708 - accuracy: 0.8142
# Epoch 47/50
# 60000/60000 [==============================] - 1s 24us/sample - loss: 0.7549 - accuracy: 0.8162
# Epoch 48/50
# 60000/60000 [==============================] - 2s 27us/sample - loss: 0.7397 - accuracy: 0.8192
# Epoch 49/50
# 60000/60000 [==============================] - 2s 30us/sample - loss: 0.7254 - accuracy: 0.8227s - loss: 0.7252 - accu
# Epoch 50/50
# 60000/60000 [==============================] - 2s 25us/sample - loss: 0.7119 - accuracy: 0.8253
#
#
# Test accuracy: 0.829

# %%
# MLP - relu

import numpy as np
import tensorflow as tf
import tensorflow.keras as keras
tf.keras.backend.set_floatx('float64')

# Data Preparation
X_train = np.load('data_mnist/X_train.npy', allow_pickle=True)
y_train = np.load('data_mnist/y_train.npy', allow_pickle=True)
X_test = np.load('data_mnist/X_test.npy', allow_pickle=True)
y_test = np.load('data_mnist/y_test.npy', allow_pickle=True)

X_train = X_train/255
X_test  = X_test/255


batch_size = 1024
epochs = 50

# create model
model = tf.keras.Sequential()
model.add(tf.keras.Input(shape=(784,)))
model.add(tf.keras.layers.Dense(128, activation='relu'))
model.add(tf.keras.layers.Dense(10, activation='softmax'))

# declare optimization method and loss function
model.compile(optimizer='sgd', 
              loss='sparse_categorical_crossentropy', 
              metrics=['accuracy'])

# training
history = model.fit(X_train, y_train, batch_size, epochs)

# testing
test_loss, test_acc = model.evaluate(X_test, y_test, verbose=0)
print('\n\nTest accuracy:', test_acc)
# Out:
# Train on 60000 samples
# Epoch 1/50
# 60000/60000 [==============================] - 2s 33us/sample - loss: 2.1555 - accuracy: 0.2590
# Epoch 2/50
# 60000/60000 [==============================] - 1s 23us/sample - loss: 1.7195 - accuracy: 0.6320
# Epoch 3/50
# 60000/60000 [==============================] - 1s 23us/sample - loss: 1.3816 - accuracy: 0.7449s - loss: 1.4307 - accuracy:  - ETA: 0s - loss: 1.4111 - accura
# Epoch 4/50
# 60000/60000 [==============================] - 1s 20us/sample - loss: 1.1353 - accuracy: 0.7890
# Epoch 5/50
# 60000/60000 [==============================] - 1s 22us/sample - loss: 0.9638 - accuracy: 0.8115
# Epoch 6/50
# 60000/60000 [==============================] - 1s 20us/sample - loss: 0.8441 - accuracy: 0.8258
# Epoch 7/50
# 60000/60000 [==============================] - 1s 21us/sample - loss: 0.7584 - accuracy: 0.8371
# Epoch 8/50
# 60000/60000 [==============================] - 1s 22us/sample - loss: 0.6949 - accuracy: 0.8445
# Epoch 9/50
# 60000/60000 [==============================] - 1s 20us/sample - loss: 0.6462 - accuracy: 0.8511s
# Epoch 10/50
# 60000/60000 [==============================] - 1s 20us/sample - loss: 0.6077 - accuracy: 0.8563
# Epoch 11/50
# 60000/60000 [==============================] - 1s 19us/sample - loss: 0.5766 - accuracy: 0.8611
# Epoch 12/50
# 60000/60000 [==============================] - 1s 20us/sample - loss: 0.5507 - accuracy: 0.8650
# Epoch 13/50
# 60000/60000 [==============================] - 1s 19us/sample - loss: 0.5290 - accuracy: 0.8686
# Epoch 14/50
# 60000/60000 [==============================] - 1s 19us/sample - loss: 0.5104 - accuracy: 0.8719
# Epoch 15/50
# 60000/60000 [==============================] - 1s 19us/sample - loss: 0.4944 - accuracy: 0.8744
# Epoch 16/50
# 60000/60000 [==============================] - 1s 19us/sample - loss: 0.4803 - accuracy: 0.8771s - loss: 0.4801
# Epoch 17/50
# 60000/60000 [==============================] - 1s 19us/sample - loss: 0.4679 - accuracy: 0.8794
# Epoch 18/50
# 60000/60000 [==============================] - 1s 19us/sample - loss: 0.4568 - accuracy: 0.8814
# Epoch 19/50
# 60000/60000 [==============================] - 1s 19us/sample - loss: 0.4469 - accuracy: 0.8832
# Epoch 20/50
# 60000/60000 [==============================] - 1s 19us/sample - loss: 0.4379 - accuracy: 0.8846
# Epoch 21/50
# 60000/60000 [==============================] - 1s 19us/sample - loss: 0.4298 - accuracy: 0.8863
# Epoch 22/50
# 60000/60000 [==============================] - 1s 19us/sample - loss: 0.4223 - accuracy: 0.8876
# Epoch 23/50
# 60000/60000 [==============================] - 1s 19us/sample - loss: 0.4155 - accuracy: 0.8892
# Epoch 24/50
# 60000/60000 [==============================] - 1s 20us/sample - loss: 0.4092 - accuracy: 0.8902s - loss: 0.4
# Epoch 25/50
# 60000/60000 [==============================] - 1s 19us/sample - loss: 0.4033 - accuracy: 0.8915
# Epoch 26/50
# 60000/60000 [==============================] - 1s 19us/sample - loss: 0.3979 - accuracy: 0.8927s - loss: 0.3976 - accuracy: 0.89
# Epoch 27/50
# 60000/60000 [==============================] - 1s 19us/sample - loss: 0.3927 - accuracy: 0.8938
# Epoch 28/50
# 60000/60000 [==============================] - 1s 19us/sample - loss: 0.3880 - accuracy: 0.8947
# Epoch 29/50
# 60000/60000 [==============================] - 1s 19us/sample - loss: 0.3835 - accuracy: 0.8958
# Epoch 30/50
# 60000/60000 [==============================] - 1s 19us/sample - loss: 0.3793 - accuracy: 0.8968
# Epoch 31/50
# 60000/60000 [==============================] - 1s 20us/sample - loss: 0.3753 - accuracy: 0.8974
# Epoch 32/50
# 60000/60000 [==============================] - 1s 20us/sample - loss: 0.3716 - accuracy: 0.8982s - loss: 0.3700 -
# Epoch 33/50
# 60000/60000 [==============================] - 1s 21us/sample - loss: 0.3680 - accuracy: 0.8989
# Epoch 34/50
# 60000/60000 [==============================] - 1s 20us/sample - loss: 0.3646 - accuracy: 0.8998
# Epoch 35/50
# 60000/60000 [==============================] - 1s 20us/sample - loss: 0.3614 - accuracy: 0.9001s - loss: 0.3618 - accu
# Epoch 36/50
# 60000/60000 [==============================] - 1s 19us/sample - loss: 0.3583 - accuracy: 0.9008
# Epoch 37/50
# 60000/60000 [==============================] - 1s 19us/sample - loss: 0.3554 - accuracy: 0.9013
# Epoch 38/50
# 60000/60000 [==============================] - 1s 20us/sample - loss: 0.3525 - accuracy: 0.9019
# Epoch 39/50
# 60000/60000 [==============================] - 1s 21us/sample - loss: 0.3498 - accuracy: 0.9029
# Epoch 40/50
# 60000/60000 [==============================] - 2s 26us/sample - loss: 0.3472 - accuracy: 0.9034
# Epoch 41/50
# 60000/60000 [==============================] - 1s 24us/sample - loss: 0.3447 - accuracy: 0.9038
# Epoch 42/50
# 60000/60000 [==============================] - 1s 23us/sample - loss: 0.3422 - accuracy: 0.9045
# Epoch 43/50
# 60000/60000 [==============================] - 1s 23us/sample - loss: 0.3399 - accuracy: 0.9052
# Epoch 44/50
# 60000/60000 [==============================] - 1s 24us/sample - loss: 0.3376 - accuracy: 0.9058
# Epoch 45/50
# 60000/60000 [==============================] - 1s 22us/sample - loss: 0.3355 - accuracy: 0.9063
# Epoch 46/50
# 60000/60000 [==============================] - 1s 24us/sample - loss: 0.3334 - accuracy: 0.9064s - loss: 0.3334 -
# Epoch 47/50
# 60000/60000 [==============================] - 1s 23us/sample - loss: 0.3313 - accuracy: 0.9071
# Epoch 48/50
# 60000/60000 [==============================] - 1s 20us/sample - loss: 0.3293 - accuracy: 0.9074
# Epoch 49/50
# 60000/60000 [==============================] - 1s 20us/sample - loss: 0.3273 - accuracy: 0.9079
# Epoch 50/50
# 60000/60000 [==============================] - 1s 19us/sample - loss: 0.3255 - accuracy: 0.9083
#
#
# Test accuracy: 0.9138

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['accuracy'])
plt.xlabel('iteration')
plt.ylabel('Accuracy')

# %%
# adam

import numpy as np
import tensorflow as tf
import tensorflow.keras as keras
tf.keras.backend.set_floatx('float64')

# Data Preparation
X_train = np.load('data_mnist/X_train.npy', allow_pickle=True)
y_train = np.load('data_mnist/y_train.npy', allow_pickle=True)
X_test = np.load('data_mnist/X_test.npy', allow_pickle=True)
y_test = np.load('data_mnist/y_test.npy', allow_pickle=True)

X_train = X_train/255
X_test  = X_test/255


batch_size = 512
epochs = 50

# create model
model = tf.keras.Sequential()
model.add(tf.keras.Input(shape=(784,)))
model.add(tf.keras.layers.Dense(128, activation='relu', 
                               kernel_initializer=keras.initializers.RandomNormal(stddev=0.01),
                               bias_initializer=keras.initializers.Zeros()))
model.add(tf.keras.layers.Dense(10, activation='softmax', 
                               kernel_initializer=keras.initializers.RandomNormal(stddev=0.01),
                               bias_initializer=keras.initializers.Zeros()))

# declare optimization method and loss function
model.compile(optimizer='adam', 
              loss='sparse_categorical_crossentropy', 
              metrics=['accuracy'])

# training
history = model.fit(X_train, y_train, batch_size, epochs)

# testing
test_loss, test_acc = model.evaluate(X_test, y_test, verbose=0)
print('\n\nTest accuracy:', test_acc)
# Out:
# Train on 60000 samples
# Epoch 1/50
# 60000/60000 [==============================] - 2s 33us/sample - loss: 0.8752 - accuracy: 0.8051
# Epoch 2/50
# 60000/60000 [==============================] - 1s 25us/sample - loss: 0.3094 - accuracy: 0.9120
# Epoch 3/50
# 60000/60000 [==============================] - 1s 23us/sample - loss: 0.2536 - accuracy: 0.9288
# Epoch 4/50
# 60000/60000 [==============================] - 1s 23us/sample - loss: 0.2135 - accuracy: 0.9404
# Epoch 5/50
# 60000/60000 [==============================] - 2s 26us/sample - loss: 0.1825 - accuracy: 0.9483
# Epoch 6/50
# 60000/60000 [==============================] - 1s 24us/sample - loss: 0.1580 - accuracy: 0.9556
# Epoch 7/50
# 60000/60000 [==============================] - 1s 25us/sample - loss: 0.1390 - accuracy: 0.9606
# Epoch 8/50
# 60000/60000 [==============================] - 1s 24us/sample - loss: 0.1231 - accuracy: 0.9654s - loss: 0.1252 - accura
# Epoch 9/50
# 60000/60000 [==============================] - 2s 26us/sample - loss: 0.1101 - accuracy: 0.9687
# Epoch 10/50
# 60000/60000 [==============================] - 2s 25us/sample - loss: 0.0985 - accuracy: 0.9726
# Epoch 11/50
# 60000/60000 [==============================] - 1s 24us/sample - loss: 0.0892 - accuracy: 0.9749
# Epoch 12/50
# 60000/60000 [==============================] - 1s 25us/sample - loss: 0.0808 - accuracy: 0.9774
# Epoch 13/50
# 60000/60000 [==============================] - 1s 24us/sample - loss: 0.0735 - accuracy: 0.9793
# Epoch 14/50
# 60000/60000 [==============================] - 2s 25us/sample - loss: 0.0675 - accuracy: 0.9818
# Epoch 15/50
# 60000/60000 [==============================] - 1s 24us/sample - loss: 0.0625 - accuracy: 0.9829
# Epoch 16/50
# 60000/60000 [==============================] - 2s 25us/sample - loss: 0.0574 - accuracy: 0.9840
# Epoch 17/50
# 60000/60000 [==============================] - 1s 24us/sample - loss: 0.0531 - accuracy: 0.9854
# Epoch 18/50
# 60000/60000 [==============================] - 2s 25us/sample - loss: 0.0493 - accuracy: 0.9865
# Epoch 19/50
# 60000/60000 [==============================] - 2s 25us/sample - loss: 0.0456 - accuracy: 0.9878
# Epoch 20/50
# 60000/60000 [==============================] - 1s 25us/sample - loss: 0.0421 - accuracy: 0.9889
# Epoch 21/50
# 60000/60000 [==============================] - 1s 24us/sample - loss: 0.0391 - accuracy: 0.9896
# Epoch 22/50
# 60000/60000 [==============================] - 1s 24us/sample - loss: 0.0357 - accuracy: 0.9909
# Epoch 23/50
# 60000/60000 [==============================] - 1s 24us/sample - loss: 0.0335 - accuracy: 0.9915
# Epoch 24/50
# 60000/60000 [==============================] - 1s 23us/sample - loss: 0.0309 - accuracy: 0.9922
# Epoch 25/50
# 60000/60000 [==============================] - 1s 24us/sample - loss: 0.0286 - accuracy: 0.9932
# Epoch 26/50
# 60000/60000 [==============================] - 1s 24us/sample - loss: 0.0268 - accuracy: 0.9934
# Epoch 27/50
# 60000/60000 [==============================] - 1s 24us/sample - loss: 0.0249 - accuracy: 0.9942
# Epoch 28/50
# 60000/60000 [==============================] - 1s 24us/sample - loss: 0.0228 - accuracy: 0.9950
# Epoch 29/50
# 60000/60000 [==============================] - 1s 25us/sample - loss: 0.0213 - accuracy: 0.9953
# Epoch 30/50
# 60000/60000 [==============================] - 1s 25us/sample - loss: 0.0197 - accuracy: 0.9958
# Epoch 31/50
# 60000/60000 [==============================] - 1s 24us/sample - loss: 0.0180 - accuracy: 0.9966
# Epoch 32/50
# 60000/60000 [==============================] - 1s 24us/sample - loss: 0.0168 - accuracy: 0.9972
# Epoch 33/50
# 60000/60000 [==============================] - 1s 24us/sample - loss: 0.0159 - accuracy: 0.9972
# Epoch 34/50
# 60000/60000 [==============================] - 1s 24us/sample - loss: 0.0145 - accuracy: 0.9977
# Epoch 35/50
# 60000/60000 [==============================] - 1s 24us/sample - loss: 0.0135 - accuracy: 0.9979
# Epoch 36/50
# 60000/60000 [==============================] - 1s 25us/sample - loss: 0.0123 - accuracy: 0.9983
# Epoch 37/50
# 60000/60000 [==============================] - 1s 24us/sample - loss: 0.0117 - accuracy: 0.9984
# Epoch 38/50
# 60000/60000 [==============================] - 1s 24us/sample - loss: 0.0107 - accuracy: 0.9986
# Epoch 39/50
# 60000/60000 [==============================] - 1s 24us/sample - loss: 0.0100 - accuracy: 0.9987
# Epoch 40/50
# 60000/60000 [==============================] - 2s 26us/sample - loss: 0.0091 - accuracy: 0.9991
# Epoch 41/50
# 60000/60000 [==============================] - 2s 26us/sample - loss: 0.0083 - accuracy: 0.9990
# Epoch 42/50
# 60000/60000 [==============================] - 2s 26us/sample - loss: 0.0079 - accuracy: 0.9993
# Epoch 43/50
# 60000/60000 [==============================] - 2s 27us/sample - loss: 0.0072 - accuracy: 0.9993
# Epoch 44/50
# 60000/60000 [==============================] - 2s 25us/sample - loss: 0.0069 - accuracy: 0.9993
# Epoch 45/50
# 60000/60000 [==============================] - 1s 23us/sample - loss: 0.0061 - accuracy: 0.9995
# Epoch 46/50
# 60000/60000 [==============================] - 2s 25us/sample - loss: 0.0056 - accuracy: 0.9996
# Epoch 47/50
# 60000/60000 [==============================] - 2s 25us/sample - loss: 0.0053 - accuracy: 0.9997
# Epoch 48/50
# 60000/60000 [==============================] - 2s 27us/sample - loss: 0.0048 - accuracy: 0.9998s - loss: 0.0047 - accu
# Epoch 49/50
# 60000/60000 [==============================] - 2s 27us/sample - loss: 0.0043 - accuracy: 0.9998
# Epoch 50/50
# 60000/60000 [==============================] - 2s 27us/sample - loss: 0.0040 - accuracy: 0.9999
#
#
# Test accuracy: 0.9781

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['accuracy'])
plt.xlabel('iteration')
plt.ylabel('Accuracy')

# %%
# softmax

import numpy as np
import tensorflow as tf
import tensorflow.keras as keras
tf.keras.backend.set_floatx('float64')

# Data Preparation
X_train = np.load('data_mnist/X_train.npy', allow_pickle=True)
y_train = np.load('data_mnist/y_train.npy', allow_pickle=True)
X_test = np.load('data_mnist/X_test.npy', allow_pickle=True)
y_test = np.load('data_mnist/y_test.npy', allow_pickle=True)

X_train = X_train/255
X_test  = X_test/255


batch_size = 1024
epochs = 50

# create model
model = tf.keras.Sequential()
model.add(tf.keras.Input(shape=(784,)))
model.add(tf.keras.layers.Dense(10, activation='softmax'))

# declare optimization method and loss function
model.compile(optimizer='adam', 
              loss='sparse_categorical_crossentropy', 
              metrics=['accuracy'])

# training
history = model.fit(X_train, y_train, batch_size, epochs)

# testing
test_loss, test_acc = model.evaluate(X_test, y_test, verbose=0)
print('\n\nTest accuracy:', test_acc)
# Out:
# Train on 60000 samples
# Epoch 1/50
# 60000/60000 [==============================] - 1s 19us/sample - loss: 1.4848 - accuracy: 0.6110
# Epoch 2/50
# 60000/60000 [==============================] - 0s 7us/sample - loss: 0.7596 - accuracy: 0.8360
# Epoch 3/50
# 60000/60000 [==============================] - 1s 9us/sample - loss: 0.5758 - accuracy: 0.8653
# Epoch 4/50
# 60000/60000 [==============================] - 1s 9us/sample - loss: 0.4922 - accuracy: 0.8797
# Epoch 5/50
# 60000/60000 [==============================] - 1s 9us/sample - loss: 0.4436 - accuracy: 0.8881
# Epoch 6/50
# 60000/60000 [==============================] - 0s 7us/sample - loss: 0.4113 - accuracy: 0.8941
# Epoch 7/50
# 60000/60000 [==============================] - 0s 8us/sample - loss: 0.3880 - accuracy: 0.8986
# Epoch 8/50
# 60000/60000 [==============================] - 0s 8us/sample - loss: 0.3703 - accuracy: 0.9024
# Epoch 9/50
# 60000/60000 [==============================] - 0s 8us/sample - loss: 0.3568 - accuracy: 0.9050
# Epoch 10/50
# 60000/60000 [==============================] - 1s 9us/sample - loss: 0.3453 - accuracy: 0.9075
# Epoch 11/50
# 60000/60000 [==============================] - 0s 8us/sample - loss: 0.3360 - accuracy: 0.9094
# Epoch 12/50
# 60000/60000 [==============================] - 1s 8us/sample - loss: 0.3281 - accuracy: 0.9113
# Epoch 13/50
# 60000/60000 [==============================] - 0s 8us/sample - loss: 0.3214 - accuracy: 0.9132
# Epoch 14/50
# 60000/60000 [==============================] - 1s 9us/sample - loss: 0.3155 - accuracy: 0.9142
# Epoch 15/50
# 60000/60000 [==============================] - 0s 8us/sample - loss: 0.3103 - accuracy: 0.9154
# Epoch 16/50
# 60000/60000 [==============================] - 1s 8us/sample - loss: 0.3057 - accuracy: 0.9172
# Epoch 17/50
# 60000/60000 [==============================] - 1s 10us/sample - loss: 0.3016 - accuracy: 0.9175
# Epoch 18/50
# 60000/60000 [==============================] - 0s 8us/sample - loss: 0.2980 - accuracy: 0.9185
# Epoch 19/50
# 60000/60000 [==============================] - 0s 8us/sample - loss: 0.2948 - accuracy: 0.9187
# Epoch 20/50
# 60000/60000 [==============================] - 0s 8us/sample - loss: 0.2915 - accuracy: 0.9201
# Epoch 21/50
# 60000/60000 [==============================] - 0s 8us/sample - loss: 0.2889 - accuracy: 0.9213
# Epoch 22/50
# 60000/60000 [==============================] - 0s 8us/sample - loss: 0.2864 - accuracy: 0.9214
# Epoch 23/50
# 60000/60000 [==============================] - 1s 9us/sample - loss: 0.2838 - accuracy: 0.9219
# Epoch 24/50
# 60000/60000 [==============================] - 1s 9us/sample - loss: 0.2815 - accuracy: 0.9229
# Epoch 25/50
# 60000/60000 [==============================] - 0s 8us/sample - loss: 0.2795 - accuracy: 0.9231
# Epoch 26/50
# 60000/60000 [==============================] - 0s 8us/sample - loss: 0.2780 - accuracy: 0.9236
# Epoch 27/50
# 60000/60000 [==============================] - 0s 8us/sample - loss: 0.2759 - accuracy: 0.9240
# Epoch 28/50
# 60000/60000 [==============================] - 0s 7us/sample - loss: 0.2742 - accuracy: 0.9244
# Epoch 29/50
# 60000/60000 [==============================] - 0s 8us/sample - loss: 0.2727 - accuracy: 0.9252
# Epoch 30/50
# 60000/60000 [==============================] - 0s 8us/sample - loss: 0.2713 - accuracy: 0.9252
# Epoch 31/50
# 60000/60000 [==============================] - 0s 8us/sample - loss: 0.2699 - accuracy: 0.9254
# Epoch 32/50
# 60000/60000 [==============================] - 0s 8us/sample - loss: 0.2684 - accuracy: 0.9261
# Epoch 33/50
# 60000/60000 [==============================] - 0s 7us/sample - loss: 0.2672 - accuracy: 0.9262
# Epoch 34/50
# 60000/60000 [==============================] - 0s 8us/sample - loss: 0.2660 - accuracy: 0.9262
# Epoch 35/50
# 60000/60000 [==============================] - 1s 9us/sample - loss: 0.2649 - accuracy: 0.9270
# Epoch 36/50
# 60000/60000 [==============================] - 1s 8us/sample - loss: 0.2638 - accuracy: 0.9271
# Epoch 37/50
# 60000/60000 [==============================] - 0s 8us/sample - loss: 0.2627 - accuracy: 0.9273
# Epoch 38/50
# 60000/60000 [==============================] - 0s 8us/sample - loss: 0.2619 - accuracy: 0.9276
# Epoch 39/50
# 60000/60000 [==============================] - 0s 8us/sample - loss: 0.2608 - accuracy: 0.9277
# Epoch 40/50
# 60000/60000 [==============================] - 0s 8us/sample - loss: 0.2600 - accuracy: 0.9282
# Epoch 41/50
# 60000/60000 [==============================] - 1s 8us/sample - loss: 0.2589 - accuracy: 0.9282
# Epoch 42/50
# 60000/60000 [==============================] - 1s 8us/sample - loss: 0.2582 - accuracy: 0.92840s - loss: 0.2540 - ac
# Epoch 43/50
# 60000/60000 [==============================] - 1s 9us/sample - loss: 0.2574 - accuracy: 0.9288
# Epoch 44/50
# 60000/60000 [==============================] - 1s 8us/sample - loss: 0.2566 - accuracy: 0.9286
# Epoch 45/50
# 60000/60000 [==============================] - 0s 8us/sample - loss: 0.2560 - accuracy: 0.9294
# Epoch 46/50
# 60000/60000 [==============================] - 0s 8us/sample - loss: 0.2552 - accuracy: 0.9291
# Epoch 47/50
# 60000/60000 [==============================] - 1s 9us/sample - loss: 0.2546 - accuracy: 0.9297
# Epoch 48/50
# 60000/60000 [==============================] - 1s 9us/sample - loss: 0.2538 - accuracy: 0.92990s - loss: 0.2550 -
# Epoch 49/50
# 60000/60000 [==============================] - 0s 8us/sample - loss: 0.2533 - accuracy: 0.9298
# Epoch 50/50
# 60000/60000 [==============================] - 1s 9us/sample - loss: 0.2526 - accuracy: 0.9303
#
#
# Test accuracy: 0.9275

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['accuracy'])
plt.xlabel('iteration')
plt.ylabel('Accuracy')
# Out:
# Text(0, 0.5, 'Accuracy')
